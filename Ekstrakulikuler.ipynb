# %%
import statistics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("     =====soal 1=====")
print("yang mengikuti eskul di kelas 10")
print()
Paskibra = 5
PMR = 18
Pramuka = 30
Futsal = 7
Volly = 16
kesenian = 19
Rohis = 12

hasil = 5 + 18 + 30 + 7 + 16 + 19 + 12
print("maka siswa yang mengikuti eskul di kelas 10 adalah : " + str(hasil))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
jurusan = ['kelas 10 Rpl','PH','OTKP']
siswa = [107, 90, 120]
c = ['blue','green','red']
plt.title("PPDB SMK AL MADANI GARUT")
plt.bar(jurusan, siswa, color = c)
plt.show()

print("     =====soal 2=====")
print("yang mengikuti eskul di setiap bidang dan setiap kelas")
print()

a = 5
b = 21
c = 6

print("maka siswa yang mengikuti Paskibra adalah : " + str(a+b+c) + (" orang"))

a = 18
b = 4
c = 12

print("maka siswa yang mengikuti PMR adalah : " + str(a+b+c) + (" orang"))

a = 30
b = 8
c = 24

print("maka siswa yang mengikuti Pramuka adalah : " + str(a+b+c) + (" orang"))

a = 7
b = 29
c = 15

print("maka siswa yang mengikuti Futsal adalah : " + str(a+b+c) + (" orang"))

a = 16
b = 10
c = 12

print("maka siswa yang mengikuti Volly adalah : " + str(a+b+c) + (" orang"))

a = 19
b = 18
c = 4

print("maka siswa yang mengikuti Kesenian adalah : " + str(a+b+c) + (" orang"))

a = 12
b = 10
c = 7

print("maka siswa yang mengikuti Paskibra adalah : " + str(a+b+c) + (" orang"))

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
eskul = ['Paskibra','PMR','Pramuka','Futsal','Volly','kesenian','Rohis']
jumlah_orang = [32, 34, 62, 51, 38, 41, 29]
c = ['blue','green','red','pink','black','purple']
plt.title("PPDB SMK AL MADANI GARUT")
plt.bar(eskul, jumlah_orang, color = c)
plt.show()


print("     =====soal 3=====")

a = 7
b = 29
c = 15
d = 16
e = 10
f = 12
m = 287
td = 45

hasil = a + b + c + d + e + f
hasil2 = m - hasil
print("maka jumlah yang mengikuti olah raga adalah : " + str(hasil))
print("maka " + str(hasil2))
print("" + str(td))
hasil4 = (hasil / 332) * 100
hasil5 = (hasil2 / 332) * 100
hasil6 = (td / 332) * 100
print("" + str(hasil4))
print("" + str(hasil5))
print("" + str(hasil))

print("     =====soal 4=====")
print("jumlah siswa yang tidak mengikuti eskul")
print()
tidak_mengikuti_kelas_10 =17
tidak_mengikuti_kelas_11 =8
tidak_mengikuti_kelas_12 =20

kelas_10 = 17
kelas_11 = 8
kelas_12 = 20

print("maka yang tidak mengikuti eskul dari kelas 10 adalah : " + str(kelas_10))
print("maka yang tidak mengikuti eskul dari kelas 11 adalah : " + str(kelas_11))
print("maka yang tidak mengikuti eskul dari kelas 12 adalah : " + str(kelas_12))


print("     =====soal 5=====")
print("setiap tingkatan yang mengikuti eskul")
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
kelas = ['Paskibra','PMR','Pramuka','Futsal','Volly','kesenian','rohis']
jumlah_orang = [5,18 , 30, 7, 16, 19, 12]
c = ['blue','green','red']
plt.title("jumlah siswa yang mengikuti eskul 10")
plt.bar(kelas, jumlah_orang, color = c)
plt.show()

print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data siswa yang mengikuti eskul 10")
kelas = ['Paskibra','PMR','Pramuka','Futsal','Volly','kesenian','rohis']
jumlah_orang = [5,18 , 30, 7, 16, 19, 12]
ax.pie(jumlah_orang,labels = kelas,autopct='%1.2f%%')
plt.show()

print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
kelas = ['Paskibra','PMR','Pramuka','Futsal','Volly','kesenian','rohis']
jumlah_orang = [21, 4, 8, 29, 10, 18, 10]
c = ['blue','green','red']
plt.title("jumlah siswa yang mengikuti eskul 11")
plt.bar(kelas, jumlah_orang, color = c)
plt.show()

print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data siswa yang mengikuti eskul 11")
kelas = ['Paskibra','PMR','Pramuka','Futsal','Volly','kesenian','rohis']
jumlah_orang = [21, 4, 8, 29, 10, 18, 10]
ax.pie(jumlah_orang,labels = kelas,autopct='%1.2f%%')
plt.show()

print()


fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
kelas = ['Paskibra','PMR','Pramuka','Futsal','Volly','kesenian','rohis']
jumlah_orang = [6, 12, 24, 15, 12, 4, 7]
c = ['blue','green','red']
plt.title("jumlah siswa yang mengikuti eskul 12")
plt.bar(kelas, jumlah_orang, color = c)
plt.show()

print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data siswa yang mengikuti eskul 12")
kelas = ['Paskibra','PMR','Pramuka','Futsal','Volly','kesenian','rohis']
jumlah_orang = [6, 12, 24, 15, 12, 4, 7]
ax.pie(jumlah_orang,labels = kelas,autopct='%1.2f%%')
plt.show()

print()
# Out:
#      =====soal 1=====
# yang mengikuti eskul di kelas 10
#
# maka siswa yang mengikuti eskul di kelas 10 adalah : 107
#      =====soal 2=====
# yang mengikuti eskul di setiap bidang dan setiap kelas
#
# maka siswa yang mengikuti Paskibra adalah : 32 orang
# maka siswa yang mengikuti PMR adalah : 34 orang
# maka siswa yang mengikuti Pramuka adalah : 62 orang
# maka siswa yang mengikuti Futsal adalah : 51 orang
# maka siswa yang mengikuti Volly adalah : 38 orang
# maka siswa yang mengikuti Kesenian adalah : 41 orang
# maka siswa yang mengikuti Paskibra adalah : 29 orang
#      =====soal 3=====
# maka jumlah yang mengikuti olah raga adalah : 89
#      =====soal 4=====
# jumlah siswa yang tidak mengikuti eskul
#
# maka yang tidak mengikuti eskul dari kelas 10 adalah : 17
# maka yang tidak mengikuti eskul dari kelas 11 adalah : 8
# maka yang tidak mengikuti eskul dari kelas 12 adalah : 20
#      =====soal 5=====
# setiap tingkatan yang mengikuti eskul
