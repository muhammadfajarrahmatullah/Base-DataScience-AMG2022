# %%
import statistics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("=====soal 1=====")
burger = 24000
pizza = 52000
dimsum = 30000
ekkado = 7500
milkshake = 10000
eskrim = 15000

burger1 = 6
pizza1 = 3
dimsum1 = 4
eskrim1 = 5
milkshake1 = 2
ekkado1 = 4
total = 24

hasil = ((burger * burger1) + (pizza * pizza1) + (dimsum * dimsum1) + (eskrim * eskrim1) + (milkshake * milkshake1) + (ekkado * ekkado1))
print("maka hasil makanan yang di pesan adalah : " + str(hasil))

jb =((burger1 + pizza1 + dimsum1 + eskrim + milkshake1 + ekkado1)) 
print("maka belanjaannya" + str(jb))
print()
print("=====soal 2=====")
jb1 =(burger1 / 24) * 100
jb2 =(pizza1 / 24) *100
jb3 =(dimsum1 / 24) * 100
jb4 =(eskrim1 / 24) * 100
jb5 =(milkshake1 / 24) * 100
jb6 =(ekkado1 / 24) * 100

print("burger1 :" + str(jb1))
print("pizza1 :" + str(jb2))
print("dimsum1 :" + str(jb3))
print("eskrim1 :" + str(jb4))
print("milkshake1 :" + str(jb5))
print("ekkado1 :" + str(jb6))

print()
print("=====soal 3=====")
print("=====Ahmad=====")
burger_Ahmad = 4
pizza_Ahmad = 2

hasil =( 0.70 * ((burger_Ahmad * 24000 )+( pizza_Ahmad * 52000) )) + (7.5 * 2000) -5000
print("maka total belanjaan Ahmad adalah : Rp." + str (hasil))
pulangan = (200000 - hasil)
print("maka kembalian Ahmad adalah : Rp." + str(pulangan))
print("=====Beni=====")
dimsum_Beni = 3
eskrim_Beni = 1
milkshake_Beni = 2
jarak_Beni = 4

hasil1 =(0.70 * ((dimsum_Beni * 30000) + (eskrim_Beni * 15000) + (milkshake_Beni * 10000))) + (jarak_Beni * 1800) - 5000
print("maka total belanjaan Beni adalah : Rp." + str(hasil1))
pulangan1 =(150000 - hasil1)
print("maka total kembalian Beni adlah : Rp." + str(pulangan1))
print("=====Citra=====")
eskrim_Citra = 3

hasil2 =(((eskrim_Citra * 15000) ))+ (8 * 2000) - 5000
print("maka total belanjaan Citra adalah : Rp." + str(hasil2))
pulangan2 =(60000 - hasil2)
print("maka total kembalian Citra adalah : Rp." + str(pulangan2))
print("=====Dadang=====")
burger_Dadang = 2
dimsum_Dadang = 1

hasil3 =(0.80 *((burger_Dadang * 24000) + (dimsum_Dadang * 30000))) + (5 * 1800) - 5000
print("maka total belanjaan Dadang adalah : Rp" + str(hasil3))
pulangan3 =(100000 - hasil3)
print("maka total kembalian Dadang adalah : Rp." + str(pulangan3))

print("=====Epen=====")

ekkado_Epen = 4
eskrim_Epen = 1
pizza_Epen = 1

hasil4 =(0.70 * ((ekkado_Epen * 7500) + (eskrim_Epen * 15000) + (pizza_Epen * 52000))) + (12 * 2200) - 5000
print("maka total belanja Epen adalah : Rp." + str(hasil4))
pulangan4 =(100000 - hasil4)
print("maka total kembalian Epen adalah : Rp." + str(pulangan4))

print("=====soal 4=====")

print("=====Ahmad=====")
burger_Ahmad = 4
pizza_Ahmad = 2

hasil =( 0.30 * ((burger_Ahmad * 24000 )+( pizza_Ahmad * 52000) )) + 5000
print("maka jumlah potongan Ahmad adalah : Rp." + str (hasil))
dimsum_Beni = 3
eskrim_Beni = 1
milkshake_Beni = 2
jarak_Beni = 4

hasil1 =(0.30 * ((dimsum_Beni * 30000) + (eskrim_Beni * 15000) + (milkshake_Beni * 10000))) + 5000
print("maka jumlah potongan Beni adalah : Rp." + str(hasil1))
eskrim_Citra = 3

hasil2 =(0 *((eskrim_Citra * 15000) ))+5000
print("maka jumlah potongan Citra adalah : Rp." + str(hasil2))
burger_Dadang = 2
dimsum_Dadang = 1

hasil3 =(0.20 *((burger_Dadang * 24000) + (dimsum_Dadang * 30000))) +5000
print("maka jumlah potongan Dadang adalah : Rp." + str(hasil3))
ekkado_Epen = 4
eskrim_Epen = 1
pizza_Epen = 1

hasil4 =(0.30 * ((ekkado_Epen * 7500) + (eskrim_Epen * 15000) + (pizza_Epen * 52000))) + 5000
print("maka jumlah potongan Epen adalah : Rp." + str(hasil4))

hasil5 =(hasil + hasil1 + hasil2 + hasil3 + hasil4)
print("maka jumlah total seluruhnya adalah : Rp." + str(hasil5))

print("=====soal 5=====")

a=7.5
b=2000
c=4
d=1800
e=8
f=2000
g=5
h=1800
i=12
j=2200

hasil=((a * b) + (c * d) + (e * f) + (g * h) + (i * j))
print("maka total ongkir semua pembeli adalah : Rp." + str(hasil))
# Out:
# =====soal 1=====
# maka hasil makanan yang di pesan adalah : 545000
# maka belanjaannya15019
#
# =====soal 2=====
# burger1 :25.0
# pizza1 :12.5
# dimsum1 :16.666666666666664
# eskrim1 :20.833333333333336
# milkshake1 :8.333333333333332
# ekkado1 :16.666666666666664
#
# =====soal 3=====
# =====Ahmad=====
# maka total belanjaan Ahmad adalah : Rp.150000.0
# maka kembalian Ahmad adalah : Rp.50000.0
# =====Beni=====
# maka total belanjaan Beni adalah : Rp.89700.0
# maka total kembalian Beni adlah : Rp.60300.0
# =====Citra=====
# maka total belanjaan Citra adalah : Rp.56000
# maka total kembalian Citra adalah : Rp.4000
# =====Dadang=====
# maka total belanjaan Dadang adalah : Rp66400.0
# maka total kembalian Dadang adalah : Rp.33600.0
# =====Epen=====
# maka total belanja Epen adalah : Rp.89300.0
# maka total kembalian Epen adalah : Rp.10700.0
# =====soal 4=====
# =====Ahmad=====
# maka jumlah potongan Ahmad adalah : Rp.65000.0
# maka jumlah potongan Beni adalah : Rp.42500.0
# ...
