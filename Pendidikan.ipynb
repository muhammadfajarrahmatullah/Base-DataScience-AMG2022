# %%
import statistics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("     =====soal 1=====")
S2_a = 0
S2_b = 1
S2_c = 4
S2_d = 7
S2_e = 5
S2_f = 0

hasil_S2 = 0 + 1 + 4 + 7 + 5 + 0
print("maka jumlah yang tamat S2= " + str(hasil_S2))

S1_a = 4
S1_b = 12
S1_c = 6
S1_d = 13
S1_e = 14
S1_f = 0

hasil_S1 = 4 + 12 + 6 + 13 + 14 +0
print("maka jumlah yang tamat S1= " + str(hasil_S1))

SMA_a = 12
SMA_b = 17
SMA_c = 5
SMA_d = 20
SMA_e = 11
SMA_f = 75

hasil_SMA = 12 + 17 + 5 + 20 + 11 + 75
print("maka jumlah yang tamat SMA= " + str(hasil_SMA))

SMP_a = 5
SMP_b = 6
SMP_c = 25
SMP_d = 9
SMP_e = 20
SMP_f = 15

hasil_SMP = 5 + 6 + 25 + 9 + 20 + 15
print("maka jumlah yang tamat SMP= " + str(hasil_SMP))

SD_a = 1
SD_b = 8
SD_c = 0
SD_d = 19
SD_e = 10
SD_f = 1

hasil_SD = 1 + 8 + 0 + 19 + 10 + 1
print("maka jumlah yang tamat SD= " + str(hasil_SD))

tddkth_a = 2
tddkth_b = 14
tddkth_c = 3
tddkth_d = 10
tddkth_e = 0
tddkth_f = 1

hasil_tddkth = 2 + 14 + 3 + 10 + 0 + 1
print("maka jumlah yang tidak di ketahui= " + str(hasil_tddkth))

print("     =====soal 2=====")

hasil_s2 = hasil_S2 * 0.25
hasil_s1 = hasil_S1 * 0.20
hasil_sma = hasil_SMA * 0.15
hasil_smp = hasil_SMP * 0.10
hasil_sd = hasil_SD * 0.05
hasil_td = hasil_tddkth * 0.03
print("maka indek tamat S2= " + str(hasil_s2))
print("maka indek tamat S1= " + str(hasil_s1))
print("maka indek tamat SMA= " + str(hasil_sma))
print("maka indek tamat SMP= " + str(hasil_smp))
print("maka indek tamat SD= " + str(hasil_sd))
print("maka indek tamat tddkth= " + str(hasil_td))

print("     =====soal 3=====")

print("usia 70")
index_a = 0.25
index_b = 0.20
index_c = 0.15
index_d = 0.10
index_e = 0.05
index_f = 0.03

S2 = 0 * 0.25
S1 = 4 * 0.20
SMA = 12 * 0.15
SMP = 5 * 0.10
SD = 1 * 0.05
tidak_di_ketahui = 2 * 0.03

print("maka indek tamat S2= " + str(S2))
print("maka indek tamat S1= " + str(S1))
print("maka indek tamat SMA= " + str(SMA))
print("maka indek tamat SMP= " + str(SMP))
print("maka indek tamat SD= " + str(SD))
print("maka indek tidak di ketahui= " + str(tidak_di_ketahui))

print("usia 60")
index_a = 0.25
index_b = 0.20
index_c = 0.15
index_d = 0.10
index_e = 0.05
index_f = 0.03

S2 = 1 * 0.25
S1 = 12 * 0.20
SMA = 17 * 0.15
SMP = 6 * 0.10
SD = 8 * 0.05
tidak_di_ketahui = 14 * 0.03

print("maka indek tamat S2= " + str(S2))
print("maka indek tamat S1= " + str(S1))
print("maka indek tamat SMA= " + str(SMA))
print("maka indek tamat SMP= " + str(SMP))
print("maka indek tamat SD= " + str(SD))
print("maka indek tamat tidak di ketahui= " + str(tidak_di_ketahui))

print("usia 50")
index_a = 0.25
index_b = 0.20
index_c = 0.15
index_d = 0.10
index_e = 0.05
index_f = 0.03

S2 = 4 * 0.25
S1 = 6 * 0.20
SMA = 5 * 0.15
SMP = 15 * 0.10
SD = 0 * 0.05
tidak_di_ketahui = 3 * 0.03

print("maka indek tamat S2= " + str(S2))
print("maka indek tamat S1= " + str(S1))
print("maka indek tamat SMA= " + str(SMA))
print("maka indek tamat SMP= " + str(SMP))
print("maka indek tamat SD= " + str(SD))
print("maka indek tidak di ketahui= " + str(tidak_di_ketahui))

print("usia 40")
index_a = 0.25
index_b = 0.20
index_c = 0.15
index_d = 0.10
index_e = 0.05
index_f = 0.03

S2 = 7 * 0.25
S1 = 13 * 0.20
SMA = 20 * 0.15
SMP = 9 * 0.10
SD = 19 * 0.05
tidak_di_ketahui = 10 * 0.03

print("maka indek tamat S2= " + str(S2))
print("maka indek tamat S1= " + str(S1))
print("maka indek tamat SMA= " + str(SMA))
print("maka indek tamat SMP= " + str(SMP))
print("maka indek tamat SD= " + str(SD))
print("maka indek tidak di ketahui= " + str(tidak_di_ketahui))

print("usia 30")
index_a = 0.25
index_b = 0.20
index_c = 0.15
index_d = 0.10
index_e = 0.05
index_f = 0.03

S2 = 5 * 0.25
S1 = 14 * 0.20
SMA = 11 * 0.15
SMP = 20 * 0.10
SD = 10 * 0.05
tidak_di_ketahui = 0 * 0.03

print("maka indek tamat S2= " + str(S2))
print("maka indek tamat S1= " + str(S1))
print("maka indek tamat SMA= " + str(SMA))
print("maka indek tamat SMP= " + str(SMP))
print("maka indek tamat SD= " + str(SD))
print("maka indek tidak di ketahui= " + str(tidak_di_ketahui))

print("usia 20")
index_a = 0.25
index_b = 0.20
index_c = 0.15
index_d = 0.10
index_e = 0.05
index_f = 0.03

S2 = 0 * 0.25
S1 = 0 * 0.20
SMA = 75 * 0.15
SMP = 15 * 0.10
SD = 1 * 0.05
tidak_di_ketahui = 1 * 0.03

print("maka indek tamat S2= " + str(S2))
print("maka indek tamat S1= " + str(S1))
print("maka indek tamat SMA= " + str(SMA))
print("maka indek tamat SMP= " + str(SMP))
print("maka indek tamat SD= " + str(SD))
print("maka indek tidak di ketahui= " + str(tidak_di_ketahui))

print("     ======soal 4======")
terkecil = ("70")
print("maka usia dengan indeks terkecil adalah di usia = " + str(terkecil))

print("    =====soal 5=====")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
pendidikan = ['S2','S1','SMA','SMP','SD','tidak_diketahui']
jumlah_orang = [17, 49, 140, 80, 39, 30]
c = ['blue','green','red','orange','black','yellow']
plt.title("jumlah orang yang tamat di masing masing pendidikan")
plt.bar(pendidikan, jumlah_orang, color = c)
plt.show()

print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah orang yang tamat di masing masing pendidikan")
pendidikan = ['S2','S1','SMA','SMP','SD','tidak_diketahui']
jumlah_orang = [17, 49, 140, 80, 39, 30]
ax.pie(jumlah_orang,labels = pendidikan,autopct='%1.2f%%')
plt.show()
# Out:
#      =====soal 1=====
# maka jumlah yang tamat S2= 17
# maka jumlah yang tamat S1= 49
# maka jumlah yang tamat SMA= 140
# maka jumlah yang tamat SMP= 80
# maka jumlah yang tamat SD= 39
# maka jumlah yang tidak di ketahui= 30
#      =====soal 2=====
# maka indek tamat S2= 4.25
# maka indek tamat S1= 9.8
# maka indek tamat SMA= 21.0
# maka indek tamat SMP= 8.0
# maka indek tamat SD= 1.9500000000000002
# maka indek tamat tddkth= 0.8999999999999999
#      =====soal 3=====
# usia 70
# maka indek tamat S2= 0.0
# maka indek tamat S1= 0.8
# maka indek tamat SMA= 1.7999999999999998
# maka indek tamat SMP= 0.5
# maka indek tamat SD= 0.05
# maka indek tidak di ketahui= 0.06
# usia 60
# maka indek tamat S2= 0.25
# maka indek tamat S1= 2.4000000000000004
# maka indek tamat SMA= 2.55
# maka indek tamat SMP= 0.6000000000000001
# maka indek tamat SD= 0.4
# maka indek tamat tidak di ketahui= 0.42
# usia 50
# maka indek tamat S2= 1.0
# maka indek tamat S1= 1.2000000000000002
# ...

# %%
_
