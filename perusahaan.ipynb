# %%
import statistics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("=====soal 1=====")
A_Xis = 20
B_Log = 14
C_In = 28
D_Namic = 42
E_Psilon = 18

A_Xis1 =((A_Xis * 300000) + (A_Xis * 75000))
print("maka pengeluaran gaji dan asuran perusahaan A_Xis adalah : Rp." + str(A_Xis1))
B_Log1 =((B_Log * 360000) + (B_Log * 75000))
print("maka pengeluaran gaji dan asuran perusahaan B_Log adalah : Rp." + str(B_Log1))
C_In1 =((C_In * 475000) + (C_In * 75000))
print("maka pengeluaran gaji dan asuran perusahaan C_In adalah : Rp." + str(C_In1))
D_Namic1 =((D_Namic * 580000) + (D_Namic * 75000))
print("maka pengeluaran gaji dan asuran perusahaan D_Namic adalah : Rp." + str(D_Namic1))
E_Psilon1 =((E_Psilon * 400000) + (E_Psilon * 75000))
print("maka pengeluaran gaji dan asuran perusahaan E_Psilon adalah : Rp." + str(E_Psilon1))

print("=====soal 2=====")

pajak = 0.03
utang1 = 0.08
utang2 = 0.04
utang3 = 0.12
utang4 = 0.11
utang5 = 0.03

laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000

hasil =((pajak * laba_a) + (utang1 * 280000000))
print("maka total pajak dan utang a adalah : Rp" + str(hasil))
hasil1 =((pajak * laba_b) + (utang2 * 310000000))
print("maka total pajak dan utang b adalah : Rp" + str(hasil1))
hasil2 =((pajak * laba_c) + (utang3 * 420000000))
print("maka total pajak dan utang c adalah : Rp" + str(hasil2))
hasil3 =((pajak * laba_d) + (utang4 * 550000000))
print("maka total pajak dan utang d adalah : Rp" + str(hasil3))
hasil4 =((pajak * laba_e) + (utang5 * 340000000))
print("maka total pajak dan utang e adalah : Rp" + str(hasil4))

print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
perusahaan = ['A_Xis','B_Log','C_In','D_Namic','E_Psilon']
nominal = [23375000, 13330000, 51660000, 62045000,11010000]
c = ['blue','green','red','orange','black']
plt.title("total pajak dan utang tiap perusahaan ")
plt.bar(perusahaan, nominal, color = c)
plt.show()

print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ['A_Xis','B_Log','C_In','D_Namic','E_Psilon']
nominal = [23375000, 13330000, 51660000, 62045000,11010000]
ax.pie(nominal,labels =perusahaan,autopct='%1.2f%%')
plt.show()

print("=====soal 3=====")

csr1 = 0.025
csr2 = 0.035
asset1 = 280000000
asset2 = 310000000
asset3 = 420000000
asset4 = 550000000
asset5 = 340000000

hasil =((csr1 * asset1))
print("mka total csr adalah : Rp."  + str(hasil))
hasil1 =((csr2 * asset2))
print("mka total csr adalah : Rp."  + str(hasil1))
hasil2 =((csr2 * asset3))
print("mka total csr adalah : Rp."  + str(hasil2))
hasil3 =((csr2 * asset4))
print("mka total csr adalah : Rp."  + str(hasil3))
hasil4 =((csr2 * asset5))
print("mka total csr adalah : Rp."  + str(hasil4))

print("=====soal 4=====")

laba1  = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000

hasil =((laba1 * 12) + (laba2 * 12) + (laba3 * 12) + (laba4 * 12) + (laba5 * 12))
print("maka laba semua perusahaan selama 1 tahun adalah" + str(hasil))

print("=====soal 5=====")
laba1  = 32500000
laba2 = 31000000
laba3 = 42000000
laba4 = 51500000
laba5 = 27000000

karyawan1 = 20
karyawan2 = 14
karyawan3 = 28
karyawan4 = 42
karyawan5 = 18

asset1 = 280000000
asset2 = 310000000
asset3 = 420000000
asset4 = 550000000
asset5 = 340000000

csr1 = 0.025
csr2 = 0.035

hasil_a =((laba1 * 12) - csr1 * 280000000 - (7500000 * 12) - 23375000)
print("total pendapatan bersih pertahun perusahaan a : Rp." + str(hasil_a))

hasil_b =((laba2 * 12) - csr2 * 310000000 - (6090000 * 12) -13330000)
print("total pendapatan bersih pertahun perusahaan a : Rp." + str(hasil_b))

hasil_c =((laba3 * 12) - csr2 * 420000000 - (15400000 * 12) -51660000)
print("total pendapatan bersih pertahun perusahaan a : Rp." + str(hasil_c))

hasil_d =((laba4 * 12) - csr2 * 550000000 - (27510000 * 12) -62045000)
print("total pendapatan bersih pertahun perusahaan a : Rp." + str(hasil_d))

hasil_e =((laba5 * 12) - csr2 * 340000000 - (8550000 * 12) -11010000)
print("total pendapatan bersih pertahun perusahaan a : Rp." + str(hasil_e))

print("")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1,])
perusahaan = ['A_Xis','B_Log','C_In','D_Namic','E_Psilon']
nominal = [269625000, 274740000, 252840000, 206585000,198490000]
c = ['blue','green','red','orange','black']
plt.title("Grafik batang pendapatan bersih pertahun perusahaan ")
plt.bar(perusahaan, nominal, color = c)
plt.show()

print("")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ['A_Xis','B_Log','C_In','D_Namic','E_Psilon']
nominal = [269625000, 274740000, 252840000, 206585000,198490000]
ax.pie(nominal,labels =perusahaan,autopct='%1.2f%%')
plt.show()
# Out:
# =====soal 1=====
# maka pengeluaran gaji dan asuran perusahaan A_Xis adalah : Rp.7500000
# maka pengeluaran gaji dan asuran perusahaan B_Log adalah : Rp.6090000
# maka pengeluaran gaji dan asuran perusahaan C_In adalah : Rp.15400000
# maka pengeluaran gaji dan asuran perusahaan D_Namic adalah : Rp.27510000
# maka pengeluaran gaji dan asuran perusahaan E_Psilon adalah : Rp.8550000
# =====soal 2=====
# maka total pajak dan utang a adalah : Rp23375000.0
# maka total pajak dan utang b adalah : Rp13330000.0
# maka total pajak dan utang c adalah : Rp51660000.0
# maka total pajak dan utang d adalah : Rp62045000.0
# maka total pajak dan utang e adalah : Rp11010000.0
# =====soal 3=====
# mka total csr adalah : Rp.7000000.0
# mka total csr adalah : Rp.10850000.000000002
# mka total csr adalah : Rp.14700000.000000002
# mka total csr adalah : Rp.19250000.0
# mka total csr adalah : Rp.11900000.000000002
# =====soal 4=====
# maka laba semua perusahaan selama 1 tahun adalah2208000000
# ...
